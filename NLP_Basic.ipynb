# %% [markdown]
# # Tokenization

# %%
pip install nlp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Abdul\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize

# %%
a = "Hello and welcome friends to NLP workshop. My name is Muhammad Abdullah. I will be teaching you NLP from scratch"

# %%
A = word_tokenize(a)
A
# Out:
# ['Hello',
#  'and',
#  'welcome',
#  'friends',
#  'to',
#  'NLP',
#  'workshop',
#  '.',
#  'My',
#  'name',
#  'is',
#  'Muhammad',
#  'Abdullah',
#  '.',
#  'I',
#  'will',
#  'be',
#  'teaching',
#  'you',
#  'NLP',
#  'from',
#  'scratch']

# %%
S = sent_tokenize(a)
S
# Out:
# ['Hello and welcome friends to NLP workshop.',
#  'My name is Muhammad Abdullah.',
#  'I will be teaching you NLP from scratch']

# %% [markdown]
# # Type, Length and Frequency Checking

# %%
type(A),len(A)
# Out:
# (list, 22)

# %%
from nltk.probability import FreqDist
frequency = FreqDist()

# %%
for i in A:
    frequency[i]=frequency[i]+1

frequency
# Out:
# FreqDist({'NLP': 2, '.': 2, 'Hello': 1, 'and': 1, 'welcome': 1, 'friends': 1, 'to': 1, 'workshop': 1, 'My': 1, 'name': 1, ...})

# %% [markdown]
# # Stemming

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

# %%
pst.stem("Making")
# Out:
# 'make'

# %%
for i in A:
    print(pst.stem(i))
# Out:
# hello
# and
# welcom
# friend
# to
# nlp
# workshop
# .
# my
# name
# is
# muhammad
# abdullah
# .
# i
# will
# be
# teach
# you
# nlp
# from
# scratch

# %%
pst.stem('universal')
# Out:
# 'univers'

# %%
pst.stem('universe')
# Out:
# 'univers'

# %%
pst.stem('university')
# Out:
# 'univers'

# %%
pst.stem('alumni')
# Out:
# 'alumni'

# %%
pst.stem('alumnus')
# Out:
# 'alumnu'

# %% [markdown]
# # Lemmatization

# %%
import nltk
nltk.download('wordnet')
from nltk import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Abdul\AppData\Roaming\nltk_data...

# %%
lemmatizer = WordNetLemmatizer()

# %%
pst.stem('trouble')
# Out:
# 'troubl'

# %%
lemmatizer.lemmatize('trouble')
# Out:
# 'trouble'

# %%
for i in A:
    print(lemmatizer.lemmatize(i))
# Out:
# Hello
# and
# welcome
# friend
# to
# NLP
# workshop
# .
# My
# name
# is
# Muhammad
# Abdullah
# .
# I
# will
# be
# teaching
# you
# NLP
# from
# scratch

# %%
lemmatizer.lemmatize('alumnus')
# Out:
# 'alumnus'

# %%
lemmatizer.lemmatize('alumni')
# Out:
# 'alumnus'

# %%
lemmatizer.lemmatize('universe')
# Out:
# 'universe'

# %%
lemmatizer.lemmatize('university')
# Out:
# 'university'

# %% [markdown]
# # pos_tag

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Abdul\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
for i in A:
 print(nltk.pos_tag([i]))
# Out:
# [('Hello', 'NN')]
# [('and', 'CC')]
# [('welcome', 'NN')]
# [('friends', 'NNS')]
# [('to', 'TO')]
# [('NLP', 'NN')]
# [('workshop', 'NN')]
# [('.', '.')]
# [('My', 'PRP$')]
# [('name', 'NN')]
# [('is', 'VBZ')]
# [('Muhammad', 'NN')]
# [('Abdullah', 'NN')]
# [('.', '.')]
# [('I', 'PRP')]
# [('will', 'MD')]
# [('be', 'VB')]
# [('teaching', 'VBG')]
# [('you', 'PRP')]
# [('NLP', 'NN')]
# [('from', 'IN')]
# [('scratch', 'NN')]

# %% [markdown]
# # Named entity recognition

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
text= '''Abdullah Lives in Lahore'''
words= word_tokenize(text)
postags=pos_tag(words)

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Abdul\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# True

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Abdul\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
tree = nltk.ne_chunk(postags)
print(tree)
# Out:
# (S (PERSON Abdullah/NNP) Lives/VBZ in/IN (GPE Lahore/NNP))

# %%
text= 'Abdullah wants a new Samsung device from Lahore'
words= word_tokenize(text)
postags=pos_tag(words)

# %%
tree = nltk.ne_chunk(postags)
print(tree)
# Out:
# (S
#   (PERSON Abdullah/NNP)
#   wants/VBZ
#   a/DT
#   new/JJ
#   (ORGANIZATION Samsung/NNP)
#   device/NN
#   from/IN
#   (GPE Lahore/NNP))

# %% [markdown]
# # Stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Abdul\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words=set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
msg = "My name is Muhammad Abdullah, I love making AI Engineering Notebooks. My speciality is making things easy"

words = word_tokenize(msg)

filtered_sentence = []

for w in words:
    if w not in stop_words:
        filtered_sentence.append(w)

print(words)
print(filtered_sentence)
# Out:
# ['My', 'name', 'is', 'Muhammad', 'Abdullah', ',', 'I', 'love', 'making', 'AI', 'Engineering', 'Notebooks', '.', 'My', 'speciality', 'is', 'making', 'things', 'easy']
# ['My', 'name', 'Muhammad', 'Abdullah', ',', 'I', 'love', 'making', 'AI', 'Engineering', 'Notebooks', '.', 'My', 'speciality', 'making', 'things', 'easy']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
msg = "My name my is Muhammad Abdullah, I love making AI Engineering Notebooks. My speciality is making things easy"

words = word_tokenize(msg)

filtered_sentence = []

for w in words:
    if w not in stop_words:
        filtered_sentence.append(w)

print(words)
print(filtered_sentence)
# Out:
# ['My', 'name', 'my', 'is', 'Muhammad', 'Abdullah', ',', 'I', 'love', 'making', 'AI', 'Engineering', 'Notebooks', '.', 'My', 'speciality', 'is', 'making', 'things', 'easy']
# ['My', 'name', 'Muhammad', 'Abdullah', ',', 'I', 'love', 'making', 'AI', 'Engineering', 'Notebooks', '.', 'My', 'speciality', 'making', 'things', 'easy']
