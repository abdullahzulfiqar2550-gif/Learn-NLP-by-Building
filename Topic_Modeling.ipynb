# %%
# !pip install scikit-learn

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

documents = ["machine learning artificial intelligence neural networks",
    "deep learning neural networks artificial intelligence",
    "football cricket sports team match",
    "cricket team won the sports match"]

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(documents)

lda = LatentDirichletAllocation(n_components=2, random_state=42)
lda.fit(X)

words = vectorizer.get_feature_names_out()

for i, topic in enumerate(lda.components_):
    top_words = [words[index] for index in topic.argsort()[-5:]]
    print(f"Topic {i+1}:", top_words)
# Out:
# Topic 1: ['artificial', 'intelligence', 'learning', 'networks', 'neural']
# Topic 2: ['won', 'match', 'cricket', 'sports', 'team']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

documents = ["machine learning artificial intelligence neural networks",
    "deep learning neural networks artificial intelligence",
    "football cricket sports team match",
    "cricket team won the sports match"]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

lsa = TruncatedSVD(n_components=2, random_state=42)
lsa.fit(X)

words = vectorizer.get_feature_names_out()

for i, topic in enumerate(lsa.components_):
    top_words = [words[index] for index in topic.argsort()[-5:]]
    print(f"Topic {i+1}:", top_words)
# Out:
# Topic 1: ['artificial', 'intelligence', 'learning', 'networks', 'neural']
# Topic 2: ['football', 'match', 'sports', 'team', 'cricket']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

documents = ["machine learning artificial intelligence neural networks",
    "deep learning neural networks artificial intelligence",
    "football cricket sports team match",
    "cricket team won the sports match"]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

nmf = NMF(n_components=2, random_state=42)
nmf.fit(X)

words = vectorizer.get_feature_names_out()

for i, topic in enumerate(nmf.components_):
    top_words = [words[index] for index in topic.argsort()[-5:]]
    print(f"Topic {i+1}:", top_words)
# Out:
# Topic 1: ['artificial', 'intelligence', 'learning', 'networks', 'neural']
# Topic 2: ['football', 'cricket', 'match', 'sports', 'team']
